# %% [markdown]
# <a href="https://colab.research.google.com/github/leonidke/Excel-Tutorial/blob/main/Pandas_Challenges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Sample Notebook] AfterWork: Pandas Challenge - Day 24

# %% [markdown]
# ## Pre-requisite

# %%
# Import pandas for data manipulation
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Working with datetime64[ns] Data Type

# %% [markdown]
# We work with the datetime64[ns] data type in Pandas when dealing with date and time information. This data type allows us to efficiently store and manipulate date and time values in our DataFrame. For example, in a healthcare setting, we can use the datetime64[ns] data type to analyze patient admission and discharge times, track medication administration schedules, and monitor appointment booking trends.
#
# To work with datetime64[ns] data type, we can convert existing columns to this data type using the pd.to_datetime() function, extract specific components like year, month, day, hour, minute, and second using dt accessor, and perform date arithmetic operations to calculate time differences or create new date columns.

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/e/patients_t5o08.csv')
df.head(5)
# Out:
#   Patient ID First Name Last Name  Age  Gender      Diagnosis  \
# 0       P001       John       Doe   45    Male   Hypertension
# 1       P002       Jane     Smith   32  Female       Diabetes
# 2       P003    Michael   Johnson   50    Male      Arthritis
# 3       P004      Sarah  Williams   28  Female        Anxiety
# 4       P005      David     Brown   60    Male  Heart Disease
#
#                  Treatment Admission Date Discharge Date Follow-up Date
# 0               Medication     2021-05-10     2021-05-15     2021-06-01
# 1          Diet & Exercise     2021-04-20     2021-04-25     2021-05-10
# 2         Physical Therapy     2021-06-05     2021-06-15     2021-07-01
# 3               Counseling     2021-03-15     2021-03-20     2021-04-05
# 4  Medication & Monitoring     2021-07-10     2021-07-20     2021-08-05

# %%
# Checking the columns data types
df.dtypes
# Out:
# Patient ID        object
# First Name        object
# Last Name         object
# Age                int64
# Gender            object
# Diagnosis         object
# Treatment         object
# Admission Date    object
# Discharge Date    object
# Follow-up Date    object
# dtype: object

# %%
# Convert 'Admission Date', 'Discharge Date', and 'Follow-up Date' columns to datetime64[ns]
df['Admission Date'] = pd.to_datetime(df['Admission Date'], format='mixed')
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'], format='mixed')
df['Follow-up Date'] = pd.to_datetime(df['Follow-up Date'], format='mixed')

# Checking the columns data types
df.head(5)
# Out:
#   Patient ID First Name Last Name  Age  Gender      Diagnosis  \
# 0       P001       John       Doe   45    Male   Hypertension
# 1       P002       Jane     Smith   32  Female       Diabetes
# 2       P003    Michael   Johnson   50    Male      Arthritis
# 3       P004      Sarah  Williams   28  Female        Anxiety
# 4       P005      David     Brown   60    Male  Heart Disease
#
#                  Treatment Admission Date Discharge Date Follow-up Date
# 0               Medication     2021-05-10     2021-05-15     2021-06-01
# 1          Diet & Exercise     2021-04-20     2021-04-25     2021-05-10
# 2         Physical Therapy     2021-06-05     2021-06-15     2021-07-01
# 3               Counseling     2021-03-15     2021-03-20     2021-04-05
# 4  Medication & Monitoring     2021-07-10     2021-07-20     2021-08-05

# %% [markdown]
# ### <font color="green">Challenge</font>

# %% [markdown]
# Given the dataset of clinics with information on their opening and closing times, your task is to create a new column named 'Operating Hours' that calculates the total operating hours of each clinic per day. The 'Operating Hours' column should display the time duration in hours and minutes. Use the datetime64[ns] data type and relevant functions to perform this task. You can access the dataset from the URL: https://afterwork.ai/ds/ch/clinics_k2a6w.csv

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/ch/clinics_k2a6w.csv')
df.head()
# Out:
#    Clinic ID                 Clinic Name         Specialty       Location  \
# 0        101          City Health Clinic  General Medicine       New York
# 1        102      Sunrise Medical Center        Pediatrics    Los Angeles
# 2        103  Green Valley Family Clinic   Family Medicine        Chicago
# 3        104    Ocean View Dental Clinic         Dentistry          Miami
# 4        105     Elite Orthopedic Center       Orthopedics  San Francisco
#
#     Doctor Name            Doctor Email Contact Number Opening Time  \
# 0     Dr. Smith     drsmith@example.com   123-456-7890     08:00:00
# 1   Dr. Johnson   drjohnson@example.com   234-567-8901     09:00:00
# 2     Dr. Brown     drbrown@example.com   345-678-9012     07:30:00
# 3       Dr. Lee       drlee@example.com   456-789-0123     08:30:00
# 4  Dr. Martinez  drmartinez@example.com   567-890-1234     10:00:00
#
#   Closing Time Date Established
# 0     17:00:00       2005-06-15
# 1     18:00:00       2010-03-20
# 2     16:30:00       2008-11-10
# 3     17:30:00       2015-09-25
# 4     19:00:00       2012-07-05

# %%
# Checking the columns data types
df.dtypes
# Out:
# Clinic ID            int64
# Clinic Name         object
# Specialty           object
# Location            object
# Doctor Name         object
# Doctor Email        object
# Contact Number      object
# Opening Time        object
# Closing Time        object
# Date Established    object
# dtype: object

# %%
# Convert 'Opening Time' and 'Closing Time' columns to datetime64[ns]
df['Opening Time'] = pd.to_datetime(df['Opening Time'], format='%H:%M:%S')
df['Closing Time'] = pd.to_datetime(df['Closing Time'], format='%H:%M:%S')
df['Date Established'] = pd.to_datetime(df['Date Established'], format='mixed')
# Checking the columns data types
df.dtypes
# Out:
# Clinic ID                     int64
# Clinic Name                  object
# Specialty                    object
# Location                     object
# Doctor Name                  object
# Doctor Email                 object
# Contact Number               object
# Opening Time         datetime64[ns]
# Closing Time         datetime64[ns]
# Date Established     datetime64[ns]
# Operating Hours     timedelta64[ns]
# dtype: object

# %%
# Calculate the operating hours for each clinic per day
df['Operating Hours'] = df['Closing Time'] - df['Opening Time']

# Preview the DataFrame with the new 'Operating Hours' column
df.head(5)
# Out:
#    Clinic ID                 Clinic Name         Specialty       Location  \
# 0        101          City Health Clinic  General Medicine       New York
# 1        102      Sunrise Medical Center        Pediatrics    Los Angeles
# 2        103  Green Valley Family Clinic   Family Medicine        Chicago
# 3        104    Ocean View Dental Clinic         Dentistry          Miami
# 4        105     Elite Orthopedic Center       Orthopedics  San Francisco
#
#     Doctor Name            Doctor Email Contact Number        Opening Time  \
# 0     Dr. Smith     drsmith@example.com   123-456-7890 1900-01-01 08:00:00
# 1   Dr. Johnson   drjohnson@example.com   234-567-8901 1900-01-01 09:00:00
# 2     Dr. Brown     drbrown@example.com   345-678-9012 1900-01-01 07:30:00
# 3       Dr. Lee       drlee@example.com   456-789-0123 1900-01-01 08:30:00
# 4  Dr. Martinez  drmartinez@example.com   567-890-1234 1900-01-01 10:00:00
#
#          Closing Time Date Established Operating Hours
# 0 1900-01-01 17:00:00       2005-06-15 0 days 09:00:00
# 1 1900-01-01 18:00:00       2010-03-20 0 days 09:00:00
# 2 1900-01-01 16:30:00       2008-11-10 0 days 09:00:00
# 3 1900-01-01 17:30:00       2015-09-25 0 days 09:00:00
# 4 1900-01-01 19:00:00       2012-07-05 0 days 09:00:00

# %% [markdown]
# ## 2. Using Time as the Index in Pandas DataFrames

# %% [markdown]
# We use time as the index in Pandas DataFrames to organize and access time-series data efficiently. By setting the time column as the index, we can easily perform time-based operations, such as resampling, slicing, and plotting. For example, in healthcare, we can analyze patient vital signs over time by setting the timestamp as the index.
#
# To apply this concept, we first ensure the time column is in datetime format using pd.to_datetime(). Then, we set this column as the index using set_index('time_column'). This allows us to directly access and manipulate time-series data based on specific time intervals.

# %%
# Load the dataset from the URL
df = pd.read_csv('https://afterwork.ai/ds/e/patients_idfug.csv')
df.head(2)
# Out:
#    Patient ID First Name Last Name  Age  Gender      Diagnosis     Treatment  \
# 0        1001       John       Doe   45    Male  Heart Disease    Medication
# 1        1002       Jane     Smith   32  Female       Diabetes  Diet Control
#
#   Admission Date Discharge Date       Doctor
# 0     2020-01-05     2020-01-15    Dr. Smith
# 1     2019-11-10     2019-11-20  Dr. Johnson

# %%
# Convert 'Admission Date' column to datetime format
df['Admission Date'] = pd.to_datetime(df['Admission Date'])

# Set 'Admission Date' as the index of the DataFrame
df.set_index('Admission Date', inplace=True)

# Previewing the DataFrame with 'Admission Date' as the index
df.head()
# Out:
#                 Patient ID First Name Last Name  Age  Gender  \
# Admission Date
# 2020-01-05            1001       John       Doe   45    Male
# 2019-11-10            1002       Jane     Smith   32  Female
# 2020-03-01            1003    Michael   Johnson   50    Male
# 2019-08-15            1004      Sarah  Williams   28  Female
# 2020-05-10            1005      David  Anderson   60    Male
#
#                           Diagnosis         Treatment Discharge Date  \
# Admission Date
# 2020-01-05            Heart Disease        Medication     2020-01-15
# 2019-11-10                 Diabetes      Diet Control     2019-11-20
# 2020-03-01      High Blood Pressure          Exercise     2020-03-10
# 2019-08-15                  Anxiety        Counseling     2019-08-25
# 2020-05-10                Arthritis  Physical Therapy     2020-05-20
#
#                      Doctor
# Admission Date
# 2020-01-05        Dr. Smith
# 2019-11-10      Dr. Johnson
# 2020-03-01        Dr. Brown
# 2019-08-15          Dr. Lee
# 2020-05-10        Dr. White

# %% [markdown]
# ## 3. Using map() for Column Transformations

# %% [markdown]
# We use the map() function in Pandas to apply a transformation to each element in a specific column of a DataFrame. By using map(), we can efficiently update values in a column based on a predefined mapping or function. For example, we can convert categorical values to numerical values, standardize units of measurement, or apply custom calculations to each element in a column.
#
# A real-life use case for using map() is when we need to convert a column of string values representing different categories into corresponding numerical codes for machine learning models.
#
# To apply map() for column transformations, we first define a mapping dictionary or a function that specifies how each value in the column should be transformed. Then, we use the map() function on the desired column, passing the mapping dictionary or function as an argument to perform the transformation.

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/e/patients_27ihw.csv')
df.head()

# %%
# Define a mapping dictionary to convert Gender to numerical values
gender_mapping = {'Male': 0, 'Female': 1}

# Apply the map() function to transform the 'Gender' column using the mapping dictionary
df['Gender'] = df['Gender'].map(gender_mapping)

# Preview the updated DataFrame
df.head()
# Out:
#                 Patient ID First Name Last Name  Age  Gender  \
# Admission Date
# 2020-01-05            1001       John       Doe   45       0
# 2019-11-10            1002       Jane     Smith   32       1
# 2020-03-01            1003    Michael   Johnson   50       0
# 2019-08-15            1004      Sarah  Williams   28       1
# 2020-05-10            1005      David  Anderson   60       0
#
#                           Diagnosis         Treatment Discharge Date  \
# Admission Date
# 2020-01-05            Heart Disease        Medication     2020-01-15
# 2019-11-10                 Diabetes      Diet Control     2019-11-20
# 2020-03-01      High Blood Pressure          Exercise     2020-03-10
# 2019-08-15                  Anxiety        Counseling     2019-08-25
# 2020-05-10                Arthritis  Physical Therapy     2020-05-20
#
#                      Doctor
# Admission Date
# 2020-01-05        Dr. Smith
# 2019-11-10      Dr. Johnson
# 2020-03-01        Dr. Brown
# 2019-08-15          Dr. Lee
# 2020-05-10        Dr. White

# %% [markdown]
# ### <font color="green">Challenge</font>

# %% [markdown]
# In the dataset provided at the URL: https://afterwork.ai/ds/ch/clinics_gvu57.csv, there is a column named 'Doctor Title' that contains different titles such as 'General Practitioner', 'Pediatrician', 'Dentist', etc. Your task is to create a Python code snippet that uses the map() function to encode these titles into numerical codes. Define a mapping dictionary that assigns a unique numerical code to each title and apply this transformation to the 'Doctor Title' column.

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/ch/clinics_gvu57.csv')
unique_titles = df['Doctor Title'].unique()

# %%
# Define a mapping dictionary to convert Doctor Title to numerical values
unique_titles = np.unique(df['Doctor Title'])

# Apply the map() function to transform the 'Doctor Title' column using the mapping dictionary
title_to_code = {title: code for code, title in enumerate(unique_titles)}
df['Doctor Title'] = df['Doctor Title'].map(title_to_code)
# Preview the updated DataFrame

df.head(2)
# Out:
#    Clinic ID             Clinic Name  Location         Specialty  Doctor Name  \
# 0        101      City Health Clinic  Downtown  General Medicine    Dr. Smith
# 1        102  Sunrise Medical Center    Uptown        Pediatrics  Dr. Johnson
#
#    Doctor Title           Doctor Email Contact Number Opening Hours  Rating
# 0            13    drsmith@example.com   123-456-7890       8am-5pm     4.5
# 1            29  drjohnson@example.com   234-567-8901       9am-6pm     4.2

# %% [markdown]
# ## 4. Manipulating the Index with Resetting and Setting in Pandas

# %% [markdown]
# We manipulate the index of a DataFrame by resetting and setting it using the Pandas library. Resetting the index means converting the current index into a column and replacing it with a default integer index. This can be useful when we want to remove the current index or when we need to reset the index after filtering or sorting operations.
#
# On the other hand, setting the index allows us to specify a column or a combination of columns as the new index of the DataFrame. This is helpful when we want to organize the data based on specific columns or when we need to perform operations that require a unique identifier as the index. For example, in a healthcare dataset, we can reset the index to default integers after filtering out irrelevant rows, and then set the 'Patient ID' column as the new index to easily access and analyze patient-specific data.

# %%
# Loading the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/e/patients_zsu3g.csv')

# Previewing the original DataFrame
df.head()
# Out:
#    Patient ID First Name Last Name  Age  Gender     Diagnosis  \
# 0         101      Emily     Smith   45  Female  Hypertension
# 1         102      James   Johnson   60    Male      Diabetes
# 2         103      Sarah  Williams   35  Female       Anxiety
# 3         104    Michael     Brown   50    Male     Arthritis
# 4         105      Linda  Anderson   55  Female    Depression
#
#                    Treatment Admission Date Discharge Date  Room Number
# 0                 Medication     2021-05-10     2021-05-15          101
# 1          Diet and Exercise     2021-06-02     2021-06-10          102
# 2                    Therapy     2021-07-15     2021-07-20          103
# 3           Physical Therapy     2021-08-03     2021-08-15          104
# 4  Medication and Counseling     2021-09-20     2021-09-30          105

# %%
# Resetting the index to default integers
df_reset = df.reset_index()

# Previewing the DataFrame after resetting the index
df_reset.head()
# Out:
#    index  Patient ID First Name Last Name  Age  Gender     Diagnosis  \
# 0      0         101      Emily     Smith   45  Female  Hypertension
# 1      1         102      James   Johnson   60    Male      Diabetes
# 2      2         103      Sarah  Williams   35  Female       Anxiety
# 3      3         104    Michael     Brown   50    Male     Arthritis
# 4      4         105      Linda  Anderson   55  Female    Depression
#
#                    Treatment Admission Date Discharge Date  Room Number
# 0                 Medication     2021-05-10     2021-05-15          101
# 1          Diet and Exercise     2021-06-02     2021-06-10          102
# 2                    Therapy     2021-07-15     2021-07-20          103
# 3           Physical Therapy     2021-08-03     2021-08-15          104
# 4  Medication and Counseling     2021-09-20     2021-09-30          105

# %%
# Setting the 'Patient ID' column as the new index
df_set = df.set_index('Patient ID')

# Previewing the DataFrame after setting the 'Patient ID' as the index
df_set.head()
# Out:
#            First Name Last Name  Age  Gender     Diagnosis  \
# Patient ID
# 101             Emily     Smith   45  Female  Hypertension
# 102             James   Johnson   60    Male      Diabetes
# 103             Sarah  Williams   35  Female       Anxiety
# 104           Michael     Brown   50    Male     Arthritis
# 105             Linda  Anderson   55  Female    Depression
#
#                             Treatment Admission Date Discharge Date  \
# Patient ID
# 101                        Medication     2021-05-10     2021-05-15
# 102                 Diet and Exercise     2021-06-02     2021-06-10
# 103                           Therapy     2021-07-15     2021-07-20
# 104                  Physical Therapy     2021-08-03     2021-08-15
# 105         Medication and Counseling     2021-09-20     2021-09-30
#
#             Room Number
# Patient ID
# 101                 101
# 102                 102
# 103                 103
# 104                 104
# 105                 105

# %% [markdown]
# ## 5. Chunking Large Datasets for Efficient Processing

# %% [markdown]
# We chunk large datasets into smaller, more manageable pieces to optimize processing speed and memory usage. By breaking down the dataset into chunks, we can perform operations on each smaller portion individually, reducing the strain on system resources. For example, in healthcare analytics, we may have a massive dataset of patient records that we need to analyze. By chunking the data, we can process one segment at a time, allowing us to handle large volumes of information without overwhelming the system.
#
# To apply chunking in Pandas, we can use the 'chunksize' parameter when reading a large dataset with 'pd.read_csv()', which divides the data into chunks based on the specified size.

# %%
# Define the URL for the dataset
url = 'https://afterwork.ai/ds/e/patients_v5wmh.csv'

# Specify the chunk size for processing
chunk_size = 3

# Read the dataset in chunks using pd.read_csv()
for chunk in pd.read_csv(url, chunksize=chunk_size):
    # Perform operations on each chunk
    print(chunk)
# Out:
#    Patient ID First Name Last Name  Age  Gender      Diagnosis   Treatment  \
# 0        1001       John       Doe   45    Male  Heart Disease  Medication
# 1        1002       Jane     Smith   32  Female      Influenza        Rest
# 2        1003    Michael   Johnson   60    Male       Diabetes        Diet
#
#   Admission Date Discharge Date       Doctor
# 0     2020-05-10     2020-05-20    Dr. Smith
# 1     2020-06-15     2020-06-20  Dr. Johnson
# 2     2020-07-01     2020-07-10    Dr. Brown
#    Patient ID First Name Last Name  Age  Gender            Diagnosis  \
#
patient ID First Name Last Name  Age  Gender            Diagnosis  \
# 63        1064  Alexander    Flores   27  Female              Anxiety
# 64        1065    Madison    Rivera   49    Male  Alzheimer's Disease
# 65        1066      David  Gonzalez   36  Female             Insomnia
#
#                   Treatment Admission Date Discharge Date         Doctor
# 63  Medication & Counseling     2026-08-01     2026-08-10     Dr. Taylor
# 64         Memory Exercises     2026-09-10     2026-09-20   Dr. Martinez
# 65            Sleep Therapy     2026-10-15     2026-10-25  Dr. Rodriguez
#     Patient ID First Name Last Name  Age  Gender     Diagnosis  \
# 66        1067     Sophia     Kelly   60    Male          PTSD
# 67        1068      James     Baker   37  Female        Asthma
# 68        1069     Olivia    Garcia   52    Male  Osteoporosis
#
#                         Treatment Admission Date Discharge Date     Doctor
# 66           Therapy & Medication     2026-11-20     2026-11-30  Dr. Lewis
# 67             Inhaler & Exercise     2026-12-25     2027-01-05  Dr. Scott
# 68  Medication & Physical Therapy     2027-02-01     2027-02-10   Dr. King
#     Patient ID First Name Last Name  Age  Gender            Diagnosis  \
# 69        1070    William  Martinez   28  Female              Anxiety
# 70        1071       Emma    Rivera   43    Male  High Blood Pressure
# 71        1072       Jack  Gonzalez   58  Female            Arthritis
#
#            Treatment Admission Date Discharge Date         Doctor
# 69        Counseling     2027-03-10     2027-03-20      Dr. Young
# 70          Exercise     2027-04-15     2027-04-25  Dr. Hernandez
# 71  Physical Therapy     2027-05-20     2027-05-30      Dr. Adams
#     Patient ID First Name Last Name  Age  Gender Diagnosis          Treatment  \
# 72        1073        Mia     Kelly   34    Male   Obesity    Diet & Exercise
# 73        1074       Liam     Baker   48  Female  Migraine  Rest & Medication
# 74        1075        Ava     Lopez   30    Male    Cancer       Chemotherapy
#
#    Admission Date Discharge Date      Doctor
# 72     2027-06-25     2027-07-05  Dr. Garcia
# 73     2027-08-01     2027-08-10   Dr. Perez
# 74     2027-09-10     2027-09-20  Dr. Taylor

# %% [markdown]
# ### <font color="green">Challenge</font>

# %% [markdown]
# Write a Python code snippet that reads the dataset from the following URL: https://afterwork.ai/ds/ch/clinics_ul0qi.csv and displays the chunks of data without performing any operations. Make use of the 'chunksize' parameter in 'pd.read_csv()' to chunk the dataset.

# %%
# Define the URL for the dataset
url = 'https://afterwork.ai/ds/ch/clinics_ul0qi.csv'

# Specify the chunk size for processing
chunk_size = 10

# Read the dataset in chunks using pd.read_csv()
for chunk in pd.read_csv(url, chunksize=chunk_size):

    # Perform operations on each chunk
    print(chunk)
# Out:
#    Clinic ID      Clinic Name       Location         Specialty  Doctors  \
# 0        101   Central Clinic       New York  General Medicine        5
# 1        102  Westside Clinic    Los Angeles       Dermatology        3
# 2        103  East End Clinic        Chicago        Pediatrics        4
# 3        104     South Clinic          Miami        Cardiology        6
# 4        105     North Clinic        Seattle       Orthopedics        5
# 5        106  Downtown Clinic  San Francisco        Obstetrics        4
# 6        107    Uptown Clinic         Boston     Ophthalmology        3
# 7        108  Suburban Clinic         Dallas               ENT        5
# 8        109     Rural Clinic         Denver           Urology        2
# 9        110     Metro Clinic        Phoenix        Psychiatry        4
#
#    Nurses  Patients  Appointments  Revenue  Rating
# 0      10       200           500   100000     4.5
# 1       8       150           400    90000     4.2
# 2       6       120           300    75000     4.7
# 3      12       250           600   120000     4.3
# 4       9       180           450    95000     4.6
# 5       7       140           350    80000     4.4
# 6       5       100           250    70000     4.8
# 7      10       200           500   100000     4.5
# 8       4        80           200    60000     4.1
# 9       8       160           400    85000     4.9
#     Clinic ID      Clinic Name      Location               Specialty  Doctors  \
# 10        111   Coastal Clinic     San Diego               Neurology        3
# 11        112  Mountain Clinic      Portland           Endocrinology        2
# 12        113    Valley Clinic       Houston        Gastroenterology        5
# 13        114    Island Clinic      Honolulu         Plastic Surgery        3
# 14        115  Lakeside Clinic   Minneapolis        Physical Therapy        4
# 15        116    Harbor Clinic  Philadelphia  Cardiovascular Surgery        6
# 16        117    Desert Clinic     Las Vegas                Oncology        4
# 17        118   Prairie Clinic   Kansas City            Rheumatology        3
# 18        119    Forest Clinic       Atlanta             Dermatology        5
# 19        120     Beach Clinic         Miami              Obstetrics        4
#
#     Nurses  Patients  Appointments  Revenue  Rating
# 10       6       130           320    75000     4.2
# 11       3        70           180    55000     4.6
# 12      11       220           550   110000     4.4
# 13       5        90           230    65000     4.7
# 14       7       150           380    80000     4.3
# 15      10       200           500   120000     4.5
# 16       8       170           420    90000     4.2
# 17       6       120           300    75000     4.6
# 18       9       190           480    95000     4.8
# 19       7       140           350    80000     4.4
#     Clinic ID         Clinic Name       Location          Specialty  Doctors  \
# 20        121  Countryside Clinic        Chicago    Family Medicine        6
# 21        122        Urban Clinic       New York  Internal Medicine        5
# 22        123     Suburban Clinic    Los Angeles        Orthopedics        4
# 23        124        Rural Clinic         Dallas                ENT        3
# 24        125        Metro Clinic        Seattle         Psychiatry        5
# 25        126      Coastal Clinic  San Francisco          Neurology        4
# 26        127     Mountain Clinic         Boston      Endocrinology        3
# 27        128       Valley Clinic         Denver   Gastroenterology        5
# 28        129       Island Clinic        Phoenix    Plastic Surgery        2
# 29        130     Lakeside Clinic      San Diego   Physical Therapy        4
#
#     Nurses  Patients  Appointments  Revenue  Rating
# 20      12       230           580   110000     4.5
# 21      10       200           500   100000     4.2
# 22       8       160           400    85000     4.7
# 23       6       100           250    70000     4.3
# 24       9       180           450    95000     4.6
# 25       7       140           350    80000     4.4
# 26       5       110           270    65000     4.9
# 27      11       220           550   110000     4.2
# 28       4        80           200    60000     4.7
# 29       8       160           400    85000     4.3
#     Clinic ID         Clinic Name      Location               Specialty  \
# 30        131       Harbor Clinic      Portland  Cardiovascular Surgery
# 31        132       Desert Clinic       Houston                Oncology
# 32        133      Prairie Clinic      Honolulu            Rheumatology
# 33        134       Forest Clinic   Minneapolis             Dermatology
# 34        135        Beach Clinic  Philadelphia              Obstetrics
# 35        136  Countryside Clinic     Las Vegas         Family Medicine
# 36        137        Urban Clinic   Kansas City       Internal Medicine
# 37        138     Suburban Clinic       Atlanta             Orthopedics
# 38        139        Rural Clinic         Miami                     ENT
# 39        140        Metro Clinic       Chicago              Psychiatry
#
#     Doctors  Nurses  Patients  Appointments  Revenue  Rating
# 30        6      10       200           500   120000     4.5
# 31        5       9       190           480    95000     4.2
# 32        3       6       120           300    75000     4.6
# 33        4       7       150           380    80000     4.8
# 34        5      10       200           500   100000     4.4
# 35        4       8       160           400    85000     4.7
# 36        3       6       100           250    70000     4.3
# 37        5       9       180           450    95000     4.6
# 38        4       7       140           350    80000     4.4
# 39        3       5       110           270    65000     4.9
#     Clinic ID      Clinic Name       Location               Specialty  \
# 40        141   Coastal Clinic       New York               Neurology
# 41        142  Mountain Clinic    Los Angeles           Endocrinology
# 42        143    Valley Clinic         Dallas        Gastroenterology
# 43        144    Island Clinic        Seattle         Plastic Surgery
# 44        145  Lakeside Clinic  San Francisco        Physical Therapy
# 45        146    Harbor Clinic         Boston  Cardiovascular Surgery
# 46        147    Desert Clinic         Denver                Oncology
# 47        148   Prairie Clinic        Phoenix            Rheumatology
# 48        149    Forest Clinic      San Diego             Dermatology
# 49        150     Beach Clinic       Portland              Obstetrics
#
#     Doctors  Nurses  Patients  Appointments  Revenue  Rating
# 40        5      11       220           550   110000     4.2
# 41        2       4        80           200    60000     4.7
# 42        4       8       160           400    85000     4.3
# 43        6      10       200           500   120000     4.5
# 44        5       9       190           480    95000     4.2
# 45        3       6       120           300    75000     4.6
# 46        4       7       150           380    80000     4.8
# 47        5      10       200           500   100000     4.4
# 48        4       8       160           400    85000     4.7
# 49        3       5       110           270    65000     4.9
#     Clinic ID         Clinic Name      Location          Specialty  Doctors  \
# 50        151  Countryside Clinic       Houston    Family Medicine        5
# 51        152        Urban Clinic      Honolulu  Internal Medicine        4
# 52        153     Suburban Clinic   Minneapolis        Orthopedics        3
# 53        154        Rural Clinic  Philadelphia                ENT        5
# 54        155        Metro Clinic     Las Vegas         Psychiatry        4
# 55        156      Coastal Clinic   Kansas City          Neurology        2
# 56        157     Mountain Clinic       Atlanta      Endocrinology        4
# 57        158       Valley Clinic         Miami   Gastroenterology        6
# 58        159       Island Clinic       Chicago    Plastic Surgery        5
# 59        160     Lakeside Clinic      New York   Physical Therapy        3
#
#     Nurses  Patients  Appointments  Revenue  Rating
# 50      11       220           550   110000     4.2
# 51       7       140           350    80000     4.5
# 52       6       100           250    70000     4.3
# 53       9       180           450    95000     4.6
# 54       7       140           350    80000     4.4
# 55       4        80           200    60000     4.7
# 56       8       160           400    85000     4.3
# 57      10       200           500   100000     4.8
# 58       9       190           480    95000     4.2
# 59       6       120           300    75000     4.6
#     Clinic ID         Clinic Name       Location               Specialty  \
# 60        161       Harbor Clinic    Los Angeles  Cardiovascular Surgery
# 61        162       Desert Clinic        Chicago                Oncology
# 62        163      Prairie Clinic          Miami            Rheumatology
# 63        164       Forest Clinic        Seattle             Dermatology
# 64        165        Beach Clinic  San Francisco              Obstetrics
# 65        166  Countryside Clinic         Boston         Family Medicine
# 66        167        Urban Clinic         Dallas       Internal Medicine
# 67        168     Suburban Clinic         Denver             Orthopedics
# 68        169        Rural Clinic        Phoenix                     ENT
# 69        170        Metro Clinic      San Diego              Psychiatry
#
#     Doctors  Nurses  Patients  Appointments  Revenue  Rating
# 60        4       7       150           380    80000     4.7
# 61        5      11       220           550   110000     4.5
# 62        3       5       110           270    65000     4.9
# 63        4       8       160           400    85000     4.4
# 64        6      10       200           500   100000     4.2
# 65        5       9       180           450    95000     4.6
# 66        4       7       140           350    80000     4.3
# 67        3       6       100           250    70000     4.7
# 68        5      10       200           500   100000     4.5
# 69        4       8       160           400    85000     4.2
#     Clinic ID      Clinic Name      Location               Specialty  Doctors  \
# 70        171   Coastal Clinic      Portland               Neurology        3
# 71        172  Mountain Clinic       Houston           Endocrinology        2
# 72        173    Valley Clinic      Honolulu        Gastroenterology        4
# 73        174    Island Clinic   Minneapolis         Plastic Surgery        6
# 74        175  Lakeside Clinic  Philadelphia        Physical Therapy        5
# 75        176    Harbor Clinic     Las Vegas  Cardiovascular Surgery        3
# 76        177    Desert Clinic   Kansas City                Oncology        4
# 77        178   Prairie Clinic       Atlanta            Rheumatology        5
# 78        179    Forest Clinic      New York             Dermatology        4
# 79        180     Beach Clinic   Los Angeles              Obstetrics        3
#
#     Nurses  Patients  Appointments  Revenue  Rating
# 70       5       110           270    65000     4.7
# 71       4        80           200    60000     4.9
# 72       7       140           350    80000     4.4
# 73      11       220           550   110000     4.6
# 74       9       190           480    95000     4.3
# 75       6       120           300    75000     4.8
# 76       8       160           400    85000     4.2
# 77      10       200           500   100000     4.5
# 78       7       150           380    80000     4.2
# 79       6       100           250    70000     4.7
#     Clinic ID         Clinic Name       Location          Specialty  Doctors  \
# 80        181  Countryside Clinic        Chicago    Family Medicine        5
# 81        182        Urban Clinic          Miami  Internal Medicine        4
# 82        183     Suburban Clinic        Seattle        Orthopedics        3
# 83        184        Rural Clinic  San Francisco                ENT        5
# 84        185        Metro Clinic         Boston         Psychiatry        4
# 85        186      Coastal Clinic         Dallas          Neurology        2
# 86        187     Mountain Clinic         Denver      Endocrinology        4
# 87        188       Valley Clinic        Phoenix   Gastroenterology        6
# 88        189       Island Clinic      San Diego    Plastic Surgery        5
# 89        190     Lakeside Clinic       Portland   Physical Therapy        3
#
#     Nurses  Patients  Appointments  Revenue  Rating
# 80       9       180           450    95000     4.3
# 81       8       160           400    85000     4.6
# 82       5       110           270    65000     4.9
# 83      11       220           550   110000     4.4
# 84       7       140           350    80000     4.8
# 85       4        80           200    60000     4.2
# 86       7       140           350    80000     4.5
# 87      10       200           500   100000     4.3
# 88       9       190           480    95000     4.6
# 89       6       120           300    75000     4.2
#     Clinic ID         Clinic Name      Location               Specialty  \
# 90        191       Harbor Clinic       Houston  Cardiovascular Surgery
# 91        192       Desert Clinic      Honolulu                Oncology
# 92        193      Prairie Clinic   Minneapolis            Rheumatology
# 93        194       Forest Clinic  Philadelphia             Dermatology
# 94        195        Beach Clinic     Las Vegas              Obstetrics
# 95        196  Countryside Clinic   Kansas City         Family Medicine
# 96        197        Urban Clinic       Atlanta       Internal Medicine
# 97        198     Suburban Clinic      New York             Orthopedics
# 98        199        Rural Clinic   Los Angeles                     ENT
# 99        200        Metro Clinic       Chicago              Psychiatry
#
#     Doctors  Nurses  Patients  Appointments  Revenue  Rating
# 90        4       8       160           400    85000     4.7
# 91        5      10       200           500   100000     4.4
# 92        3       5       110           270    65000     4.9
# 93        4       7       140           350    80000     4.2
# 94        6      11       220           550   110000     4.5
# 95        5       9       180           450    95000     4.7
# 96        4       8       160           400    85000     4.3
# 97        3       6       100           250    70000     4.6
# 98        5      10       200           500   100000     4.2
# 99        4       7       150           380    80000     4.8

# %% [markdown]
# ## 6. Counting Distinct Elements in a DataFrame

# %% [markdown]
# We count distinct elements in a DataFrame to determine the unique values present in a specific column. This helps us understand the diversity and uniqueness of data entries. For example, in a healthcare dataset, we may want to count the distinct patient IDs to identify the total number of unique patients.
#
# To apply this concept, we use the Pandas library in Python by utilizing the nunique() method on a specific column. This method returns the count of unique elements in that column. By counting distinct elements, we can gain insights into the variety and individuality of data points, which is crucial for accurate analysis and decision-making.

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/e/patients_6l0x9.csv')
df.head()
# Out:
#    Patient ID First Name Last Name  Age  Gender      Diagnosis  \
# 0        1001       John       Doe   45    Male  Heart Disease
# 1        1002       Jane     Smith   32  Female            Flu
# 2        1003    Michael   Johnson   50    Male       Diabetes
# 3        1004      Sarah  Williams   28  Female        Allergy
# 4        1005      David  Anderson   60    Male      Arthritis
#
#           Treatment Admission Date Discharge Date       Doctor
# 0        Medication     2020-05-10     2020-05-20    Dr. Smith
# 1              Rest     2020-06-15     2020-06-20  Dr. Johnson
# 2              Diet     2020-07-01     2020-07-10    Dr. Brown
# 3        Medication     2020-08-05     2020-08-15      Dr. Lee
# 4  Physical Therapy     2020-09-10     2020-09-25    Dr. White

# %%
# Counting distinct elements in the 'Patient ID' column
distinct_patient_count = df['Patient ID'].nunique()

# Display the count of distinct patients
print('Total number of distinct patients:', distinct_patient_count)
# Out:
# Total number of distinct patients: 75

# %% [markdown]
# ## 7. Optimizing Data Processing with eval()

# %% [markdown]
# We optimize data processing by using the eval() method in Pandas. This method allows us to evaluate and execute dynamic Python expressions on DataFrame objects efficiently. We use eval() to perform complex operations on large datasets quickly, improving the performance of our code. For example, we can use eval() to filter, transform, or calculate new columns based on specific conditions without the need for multiple intermediate steps.
#
# In a real-life scenario, we can apply eval() when analyzing healthcare data to calculate aggregated statistics, filter out specific patient groups, or create new variables based on medical conditions.
#
# To apply eval(), we provide the expression as a string parameter to the eval() method, which then evaluates the expression in the context of the DataFrame, returning the result seamlessly.

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/e/patients_hg17u.csv')
df.head()
# Out:
#    Patient ID First Name Last Name  Age  Gender            Diagnosis  \
# 0        1001       John       Doe   45    Male        Heart Disease
# 1        1002       Jane     Smith   32  Female             Diabetes
# 2        1003    Michael   Johnson   50    Male  High Blood Pressure
# 3        1004      Sarah  Williams   28  Female              Anxiety
# 4        1005      David  Anderson   60    Male            Arthritis
#
#           Treatment Admission Date Discharge Date       Doctor
# 0        Medication     2020-05-10     2020-05-20    Dr. Smith
# 1           Insulin     2020-06-15     2020-06-25  Dr. Johnson
# 2          Exercise     2020-07-20     2020-07-30    Dr. Brown
# 3        Counseling     2020-08-05     2020-08-15      Dr. Lee
# 4  Physical Therapy     2020-09-10     2020-09-20   Dr. Wilson

# %%
# Use eval() to filter patients with age greater than 40
mask = df.eval('Age > 40')

# Display the filtered DataFrame
df[mask]
# Out:
#     Patient ID First Name Last Name  Age  Gender            Diagnosis  \
#
# 24  Physical Therapy     2022-05-10     2022-05-20    Dr. Wilson
# 25        Medication     2022-06-15     2022-06-25    Dr. Garcia
# 27      Chemotherapy     2022-08-05     2022-08-15     Dr. White
# 30     Sleep Therapy     2022-11-20     2022-11-30  Dr. Martinez
# 32       Antibiotics     2023-01-10     2023-01-20   Dr. Johnson
# 35          Vitamins     2023-04-05     2023-04-15     Dr. Brown
# 37        Medication     2023-06-15     2023-06-25     Dr. Smith
# 40         Diet Plan     2023-09-10     2023-09-20  Dr. Martinez
# 42  Physical Therapy     2023-11-20     2023-11-30    Dr. Wilson
# 45      Chemotherapy     2024-02-15     2024-02-25     Dr. White
# 47    Rehabilitation     2024-04-05     2024-04-15     Dr. Green
# 49         Diet Plan     2024-06-15     2024-06-25       Dr. Lee
# 51  Physical Therapy     2024-08-05     2024-08-15     Dr. Adams
# 52        Counseling     2024-09-10     2024-09-20    Dr. Wilson
# 54  Memory Exercises     2024-11-20     2024-11-30    Dr. Garcia
# 55        Medication     2024-12-05     2024-12-15     Dr. Smith
# 57           Therapy     2025-02-15     2025-02-25     Dr. Green
# 59           Therapy     2025-04-05     2025-04-15       Dr. Lee
# 60  Physical Therapy     2025-05-10     2025-05-20    Dr. Wilson
# 61        Medication     2025-06-15     2025-06-25     Dr. Brown
# 63      Chemotherapy     2025-08-05     2025-08-15     Dr. White
# 65    Rehabilitation     2025-10-15     2025-10-25     Dr. Green
# 67         Diet Plan     2025-12-05     2025-12-15       Dr. Lee
# 69  Physical Therapy     2026-02-15     2026-02-25     Dr. Adams
# 70        Counseling     2026-03-20     2026-03-30    Dr. Wilson
# 72  Memory Exercises     2026-05-10     2026-05-20    Dr. Garcia
# 73        Medication     2026-06-15     2026-06-25     Dr. Smith

# %%
# Use eval() to calculate the average age of patients
average_age = df.eval('Age.mean()')

# Display the average age
print('Average Age:', average_age)
# Out:
# Average Age: 42.36

# %% [markdown]
# ### <font color="green">Challenge</font>

# %% [markdown]
# Given the dataset of clinics available at the URL: https://afterwork.ai/ds/ch/clinics_uwcpz.csv, create a code snippet using the eval() method in Pandas to calculate the average number of patients per doctor across all clinics. You should use the 'Patients' and 'Doctors' columns from the dataset.

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/ch/clinics_uwcpz.csv')
df.head(2)
# Out:
#    Clinic ID             Clinic Name     Location         Specialty  Doctors  \
# 0        101      City Health Clinic     New York  General Medicine        5
# 1        102  Sunshine Family Clinic  Los Angeles        Pediatrics        3
#
#    Nurses  Patients  Appointments  Revenue  Rating
# 0      10       200           500   100000     4.5
# 1       5       150           400    80000     4.2

# %%
# Use eval() to calculate the average number of patients per doctor across all clinics
df['patients_per_doc'] = df.eval('Patients / Doctors')
average_patient_per_doc = df['patients_per_doc'].mean()

# Display the average number of patients per doctor
print(f"The average num of patiens per doc is {average_patient_per_doc}")
# Out:
# The average num of patiens per doc is 43.346666666666664

# %% [markdown]
# ## 8. Selecting Specific Columns with loc

# %% [markdown]
# We select specific columns with the loc method in Pandas to extract only the columns we are interested in from a DataFrame. This helps us focus on relevant data and ignore unnecessary columns. For example, in a healthcare dataset, we may want to extract columns related to patient demographics and medical history for further analysis.
#
# By using loc to select specific columns, we can easily access and work with the required information without cluttering our analysis with irrelevant data.
#
# To apply this concept, we use the loc method followed by specifying the column names we want to select within square brackets, like df.loc[:, ['column1', 'column2']]. This allows us to filter the DataFrame and retain only the specified columns for our analysis.

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/e/patients_v0gy5.csv')
df.head()
# Out:
#    Patient ID First Name Last Name  Age  Gender            Diagnosis  \
# 0        1001       John       Doe   45    Male        Heart Disease
# 1        1002       Jane     Smith   32  Female            Influenza
# 2        1003    Michael   Johnson   60    Male             Diabetes
# 3        1004      Emily  Williams   28  Female        Fractured Leg
# 4        1005      David     Brown   50    Male  High Blood Pressure
#
#     Treatment Admission Date Discharge Date       Doctor
# 0  Medication     2020-05-15     2020-06-10    Dr. Smith
# 1        Rest     2020-07-20     2020-07-25  Dr. Johnson
# 2        Diet     2020-04-10     2020-05-05          NaN
# 3     Surgery     2020-08-01     2020-08-15    Dr. Brown
# 4    Exercise     2020-03-05     2020-03-20      Dr. Lee

# %%
# Select specific columns using loc
selected_columns = df.loc[:, ['Patient ID', 'First Name', 'Last Name', 'Age', 'Gender', 'Diagnosis', 'Treatment']]

# Display the selected columns
selected_columns
# Out:
#     Patient ID First Name Last Name  Age  Gender            Diagnosis  \
# 0         1001       John       Doe   45    Male        Heart Disease
# 1         1002       Jane     Smith   32  Female            Influenza
# 2         1003    Michael   Johnson   60    Male             Diabetes
# 3         1004      Emily  Williams   28  Female        Fractured Leg
# 4         1005      David     Brown   50    Male  High Blood Pressure
# ..         ...        ...       ...  ...     ...                  ...
# 70        1071    Michael    Foster   45    Male               Anemia
# 71        1072     Sophia    Bailey   56  Female          Acid Reflux
# 72        1073      James      Gray   39    Male     High Cholesterol
# 73        1074     Olivia      Reed   53  Female            Allergies
# 74        1075    William    Cooper   32    Male            Back Pain
#
#            Treatment
# 0         Medication
# 1               Rest
# 2               Diet
# 3            Surgery
# 4           Exercise
# ..               ...
# 70          Vitamins
# 71              Diet
# 72          Exercise
# 73        Medication
# 74  Physical Therapy
#
# [75 rows x 7 columns]

# %% [markdown]
# ### <font color="green">Challenge</font>

# %% [markdown]
# Given the dataset of clinics available at the following URL: https://afterwork.ai/ds/ch/clinics_xzwhl.csv, write a Python code snippet using Pandas to select only the columns 'Clinic Name', 'Specialty', 'Doctor Name', and 'Rating' from the dataset.

# %%
# Load the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/ch/clinics_xzwhl.csv')
df.head()
# Out:
#    Clinic ID             Clinic Name     Location         Specialty  \
# 0        101             City Clinic       Austin  General Medicine
# 1        102   Healthy Living Clinic       Dallas       Dermatology
# 2        103  Family Wellness Center      Houston        Pediatrics
# 3        104       Elite Dental Care  San Antonio         Dentistry
# 4        105      Vision Care Center       Austin     Ophthalmology
#
#    Doctor Name          Doctor Title           Doctor Email Contact Number  \
# 0    Dr. Smith  General Practitioner    drsmith@example.com   123-456-7890
# 1  Dr. Johnson         Dermatologist  drjohnson@example.com   234-567-8901
# 2    Dr. Brown          Pediatrician    drbrown@example.com   345-678-9012
# 3      Dr. Lee               Dentist      drlee@example.com   456-789-0123
# 4   Dr. Garcia       Ophthalmologist   drgarcia@example.com   567-890-1234
#
#    Opening Hours  Rating
# 0        8am-5pm     4.5
# 1        9am-6pm     4.8
# 2       10am-7pm     4.2
# 3  8:30am-4:30pm     4.7
# 4  9:30am-5:30pm     4.6

# %%
# Select specific columns using loc
select_cols = ['Clinic Name', 'Specialty', 'Doctor Name','Rating' ]

# Display the selected columns
df.loc[:,select_cols]
# Out:
#                 Clinic Name             Specialty  Doctor Name  Rating
# 0               City Clinic      General Medicine    Dr. Smith     4.5
# 1     Healthy Living Clinic           Dermatology  Dr. Johnson     4.8
# 2    Family Wellness Center            Pediatrics    Dr. Brown     4.2
# 3         Elite Dental Care             Dentistry      Dr. Lee     4.7
# 4        Vision Care Center         Ophthalmology   Dr. Garcia     4.6
# ..                      ...                   ...          ...     ...
# 75        Heart Care Center            Cardiology   Dr. Powell     4.6
# 76    Allergy Relief Clinic  Allergy & Immunology   Dr. Nguyen     4.8
# 77  Senior Living Community            Geriatrics   Dr. Rivera     4.4
# 78    Hearing Aid Solutions             Audiology   Dr. Hughes     4.3
# 79     Sports Injury Clinic       Sports Medicine  Dr. Collins     4.9
#
# [80 rows x 4 columns]

# %% [markdown]
# ## 10. Viewing Summary Statistics of Data

# %% [markdown]
#  By examining summary statistics, we can understand the central tendency, dispersion, and shape of our data distribution. This helps us identify any outliers, assess data quality, and make informed decisions about further data processing. For example, we can quickly check the mean, median, standard deviation, minimum, maximum, and quartiles of numerical columns.
#
#  To view summary statistics in Pandas, we use the describe() method on a DataFrame. We can apply this concept to a healthcare dataset to understand the distribution of patient age, blood pressure, or cholesterol levels, which can aid in identifying trends or anomalies in the data.

# %%
# Loading the dataset from the provided URL
df = pd.read_csv('https://afterwork.ai/ds/e/patients_wkp97.csv')
df.head()
# Out:
#       Patient ID     Age  Gender  Height  Weight Blood Pressure  \
# 1001          45    Male     175      70  120/80         Normal
# 1002          32  Female     160      55  110/70         Normal
# 1003          50    Male     180      85  130/85           High
# 1004          28  Female     165      60  115/75         Normal
# 1005          65  Female     155      75  140/90           High
#
#       Cholesterol Level  Heart Rate          Temperature    Symptoms
# 1001                 70        98.6                Cough       Fever
# 1002                 65        98.2             Headache     Fatigue
# 1003                 75        99.0  Shortness of Breath  Chest Pain
# 1004                 60        98.0          Sore Throat  Runny Nose
# 1005                 80        99.5              Fatigue   Dizziness

# %%
# Displaying summary statistics of the dataset
summary_stats = df.describe()
summary_stats
# Out:
#        Patient ID      Gender     Height  Cholesterol Level  Heart Rate
# count   75.000000   75.000000  75.000000          75.000000   75.000000
# mean    46.853333  169.600000  76.520000          71.253333   98.730667
# std     12.924619    8.860785   9.290158           6.625286    0.464110
# min     25.000000  150.000000  55.000000          60.000000   98.000000
# 25%     36.500000  163.500000  68.000000          66.000000   98.400000
# 50%     46.000000  172.000000  75.000000          72.000000   98.700000
# 75%     56.500000  177.000000  85.000000          76.000000   99.100000
# max     74.000000  182.000000  92.000000          82.000000   99.600000
